# %%
#import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pymongo
import datetime
from flask import Flask
from sqlalchemy import create_engine
import json

# %%
#import Redfin state data
raw_state_df = pd.read_csv("Resources/state_market_tracker.tsv000", sep='\t')
raw_state_df
# Out:
#       period_begin  period_end  period_duration region_type  region_type_id  \
# 0       2019-10-01  2019-10-31               30       state               4
# 1       2021-07-01  2021-07-31               30       state               4
# 2       2016-08-01  2016-08-31               30       state               4
# 3       2013-04-01  2013-04-30               30       state               4
# 4       2019-12-01  2019-12-31               30       state               4
# ...            ...         ...              ...         ...             ...
# 27073   2012-03-01  2012-03-31               30       state               4
# 27074   2016-07-01  2016-07-31               30       state               4
# 27075   2020-11-01  2020-11-30               30       state               4
# 27076   2021-08-01  2021-08-31               30       state               4
# 27077   2012-11-01  2012-11-30               30       state               4
#
#        table_id is_seasonally_adjusted         region  city          state  \
# 0            23                      f       Oklahoma   NaN       Oklahoma
# 1            40                      f        Vermont   NaN        Vermont
# 2            10                      f  New Hampshire   NaN  New Hampshire
# 3            51                      f    Mississippi   NaN    Mississippi
# 4             2                      f       Missouri   NaN       Missouri
# ...         ...                    ...            ...   ...            ...
# 27073         6                      f       Nebraska   NaN       Nebraska
# 27074        27                      f          Idaho   NaN          Idaho
# 27075        42                      f       Virginia   NaN       Virginia
# 27076        40                      f        Vermont   NaN        Vermont
# 27077         2                      f       Missouri   NaN       Missouri
#
#        ... sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# 0      ...            0.098560    0.209877         0.083561         0.053355
# 1      ...            0.251473    0.133696         0.016402        -0.000131
# 2      ...            0.089756    0.149826         0.009592         0.002687
# 3      ...           -0.008566         NaN              NaN              NaN
# 4      ...           -0.017031    0.205339        -0.123381        -0.000410
# ...    ...                 ...         ...              ...              ...
# 27073  ...            0.021426         NaN              NaN              NaN
# 27074  ...            0.182390         NaN              NaN              NaN
# 27075  ...            0.218939    0.126582        -0.048418        -0.006751
# 27076  ...            0.234272    0.158853         0.018284         0.022594
# 27077  ...            0.008307         NaN              NaN              NaN
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                     0.301282                    -0.240768
# 1                     0.424404                    -0.064422
# 2                     0.206101                     0.061385
# 3                     0.044777                    -0.014869
# 4                     0.252082                    -0.116423
# ...                        ...                          ...
# 27073                 0.422780                     0.042801
# 27074                 0.534900                    -0.117877
# 27075                 0.380567                    -0.152381
# 27076                 0.381659                    -0.018233
# 27077                 0.034720                    -0.002745
#
#        off_market_in_two_weeks_yoy  parent_metro_region  \
# 0                        -0.122115         South Region
# 1                         0.076156     Northeast Region
# 2                         0.016779     Northeast Region
# 3                        -0.005006         South Region
# 4                         0.095007       Midwest Region
# ...                            ...                  ...
# 27073                     0.030384       Midwest Region
# 27074                    -0.004820          West Region
# 27075                     0.194669         South Region
# 27076                     0.098021     Northeast Region
# 27077                    -0.001136       Midwest Region
#
#        parent_metro_region_metro_code         last_updated
# 0                                 NaN  2022-01-09 14:29:56
# 1                                 NaN  2022-01-09 14:29:56
# 2                                 NaN  2022-01-09 14:29:56
# 3                                 NaN  2022-01-09 14:29:56
# 4                                 NaN  2022-01-09 14:29:56
# ...                               ...                  ...
# 27073                             NaN  2022-01-09 14:29:56
# 27074                             NaN  2022-01-09 14:29:56
# 27075                             NaN  2022-01-09 14:29:56
# 27076                             NaN  2022-01-09 14:29:56
# 27077                             NaN  2022-01-09 14:29:56
#
# [27078 rows x 58 columns]

# %%
#checking for outliers
raw_state_df['property_type'].value_counts()
# Out:
# All Residential              5632
# Single Family Residential    5632
# Condo/Co-op                  5496
# Multi-Family (2-4 Unit)      5406
# Townhouse                    4912
# Name: property_type, dtype: int64

# %%
#checking DC for outliers
dc_df = raw_state_df[raw_state_df['state_code'] == 'DC']
dc_df['property_type'].value_counts()
# Out:
# Single Family Residential    120
# Multi-Family (2-4 Unit)      120
# Townhouse                    120
# All Residential              120
# Condo/Co-op                  120
# Name: property_type, dtype: int64

# %%
#drop unnecessary columns
state_df = raw_state_df[["period_end", "state_code", "median_sale_price", "median_ppsf"]]
state_df
# Out:
#        period_end state_code  median_sale_price  median_ppsf
# 0      2019-10-31         OK             162200         77.0
# 1      2021-07-31         VT             317900        177.0
# 2      2016-08-31         NH             200100        155.0
# 3      2013-04-30         MS             129500         69.0
# 4      2019-12-31         MO             152000        135.0
# ...           ...        ...                ...          ...
# 27073  2012-03-31         NE             133000         74.0
# 27074  2016-07-31         ID             178400        135.0
# 27075  2020-11-30         VA             264200        122.0
# 27076  2021-08-31         VT             326800        180.0
# 27077  2012-11-30         MO             112200         68.0
#
# [27078 rows x 4 columns]

# %%
#view column types
state_df.dtypes
# Out:
# period_end            object
# state_code            object
# median_sale_price      int64
# median_ppsf          float64
# dtype: object

# %%
#cast columns to strings and date/time
state_df['period_end'] = pd.to_datetime(state_df['period_end'], format='%Y-%m-%d')
state_df['state_code'] = state_df['state_code'].astype('string')
state_df.dtypes
# Out:
# /var/folders/hd/ltllzg1x3cd1p6_w0hms1sg00000gn/T/ipykernel_30866/513362087.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['period_end'] = pd.to_datetime(state_df['period_end'], format='%Y-%m-%d')
# /var/folders/hd/ltllzg1x3cd1p6_w0hms1sg00000gn/T/ipykernel_30866/513362087.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['state_code'] = state_df['state_code'].astype('string')
# period_end           datetime64[ns]
# state_code                   string
# median_sale_price             int64
# median_ppsf                 float64
# dtype: object

# %%
#drop years 2018 and older
state_df = state_df[state_df.period_end.dt.year > 2018]
state_df
# Out:
#       period_end state_code  median_sale_price  median_ppsf
# 0     2019-10-31         OK             162200         77.0
# 1     2021-07-31         VT             317900        177.0
# 4     2019-12-31         MO             152000        135.0
# 5     2019-07-31         NM             385500        218.0
# 9     2020-03-31         OH             156100        111.0
# ...          ...        ...                ...          ...
# 27068 2020-04-30         NE             206700        103.0
# 27070 2019-12-31         OK             169500        109.0
# 27071 2019-01-31         AZ             262600        151.0
# 27075 2020-11-30         VA             264200        122.0
# 27076 2021-08-31         VT             326800        180.0
#
# [8207 rows x 4 columns]

# %%
#grab mean sale price by state
state_df_mean = state_df.groupby(['state_code']).mean()
state_df_mean.sort_values(by='median_sale_price').head()
# Out:
#             median_sale_price  median_ppsf
# state_code
# OK              162056.111111    96.811111
# OH              169773.888889   103.511111
# MS              173332.022472   104.073034
# IN              179582.876712   101.000000
# MO              181113.333333   114.316667

# %%
#grab median sale price by state
state_df_median = state_df.groupby(['state_code']).median()
state_df_median_sale = state_df_median.sort_values(by='median_sale_price')
state_df_median_sale.head()
# Out:
#             median_sale_price  median_ppsf
# state_code
# OK                   171750.0         97.5
# OH                   173250.0        110.0
# MO                   179300.0        119.0
# MS                   179500.0        105.0
# KY                   183650.0        114.0

# %%
#grab median price per square foot by state
state_df_median_ppsf = state_df_median.sort_values(by='median_ppsf')
state_df_median_ppsf.head()
# Out:
#             median_sale_price  median_ppsf
# state_code
# OK                   171750.0         97.5
# IN                   190350.0        102.0
# MS                   179500.0        105.0
# AR                   184000.0        106.0
# WV                   206900.0        109.0

# %%
#grab mean sale price by state
state_df_mean = state_df.groupby(['state_code']).mean()
state_df_mean_sale = state_df_mean.sort_values(by='median_sale_price')
state_df_mean_sale.head()
# Out:
#             median_sale_price  median_ppsf
# state_code
# OK              162056.111111    96.811111
# OH              169773.888889   103.511111
# MS              173332.022472   104.073034
# IN              179582.876712   101.000000
# MO              181113.333333   114.316667

# %%
#grab mean price per square foot by state
state_df_mean_ppsf = state_df_mean.sort_values(by='median_ppsf')
state_df_mean_ppsf.head()
# Out:
#             median_sale_price  median_ppsf
# state_code
# OK              162056.111111    96.811111
# IN              179582.876712   101.000000
# OH              169773.888889   103.511111
# MS              173332.022472   104.073034
# AR              184565.555556   107.466667

# %%
#import data scientist salary information
raw_salary_df = pd.read_csv("Resources/raw_salary_data_scientist.csv")
raw_salary_df
# Out:
#      index                                          Job Title  \
# 0        0                                     Data Scientist
# 1        1                          Healthcare Data Scientist
# 2        2                                     Data Scientist
# 3        3                                     Data Scientist
# 4        4                                     Data Scientist
# ..     ...                                                ...
# 737    950           Sr Scientist, Immuno-Oncology - Oncology
# 738    951                               Senior Data Engineer
# 739    952  Project Scientist - Auton Lab, Robotics Institute
# 740    953                               Data Science Manager
# 741    955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# 738  $72K-$133K (Glassdoor est.)
# 739   $56K-$91K (Glassdoor est.)
# 740  $95K-$160K (Glassdoor est.)
# 741  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 3    *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 737  Site Name: USA - Massachusetts - Cambridge\nPo...     3.9
# 738  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 739  The Auton Lab at Carnegie Mellon University is...     2.6
# 740  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 741  Returning Candidate? Log back in to the Career...     3.6
#
#                                    Company Name         Location  \
# 0                        Tecolote Research\n3.8  Albuquerque, NM
# 1    University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                  KnowBe4\n4.8   Clearwater, FL
# 3                                     PNNL\n3.8     Richland, WA
# 4                       Affinity Solutions\n2.9     New York, NY
# ..                                          ...              ...
# 737                                    GSK\n3.9    Cambridge, MA
# 738                             Eventbrite\n4.4    Nashville, TN
# 739         Software Engineering Institute\n2.6   Pittsburgh, PA
# 740                           Numeric, LLC\n3.2    Allentown, PA
# 741           Riverside Research Institute\n3.6  Beavercreek, OH
#
#                   Headquarters          Size  Founded  ... tensor hadoop  \
# 0                   Goleta, CA   501 - 1000      1973  ...      0      0
# 1                Baltimore, MD       10000+      1984  ...      0      0
# 2               Clearwater, FL   501 - 1000      2010  ...      0      0
# 3                 Richland, WA  1001 - 5000      1965  ...      0      0
# 4                 New York, NY     51 - 200      1998  ...      0      0
# ..                         ...           ...      ...  ...    ...    ...
# 737  Brentford, United Kingdom       10000+      1830  ...      0      0
# 738          San Francisco, CA  1001 - 5000      2006  ...      0      1
# 739             Pittsburgh, PA   501 - 1000      1984  ...      0      0
# 740            Chadds Ford, PA       1 - 50        -1  ...      0      0
# 741              Arlington, VA   501 - 1000      1967  ...      0      0
#
#     tableau bi flink  mongo  google_an    job_title_sim  seniority_by_title  \
# 0         1  1     0      0          0   data scientist                  na
# 1         0  0     0      0          0   data scientist                  na
# 2         0  0     0      0          0   data scientist                  na
# 3         0  0     0      0          0   data scientist                  na
# 4         0  0     0      0          0   data scientist                  na
# ..      ... ..   ...    ...        ...              ...                 ...
# 737       0  0     0      0          0  other scientist                  sr
# 738       0  0     0      0          0    data engineer                  sr
# 739       0  0     0      0          0  other scientist                  na
# 740       0  0     0      0          0   data scientist                  na
# 741       0  0     0      0          0  other scientist                  na
#
#      Degree
# 0         M
# 1         M
# 2         M
# 3        na
# 4        na
# ..      ...
# 737       M
# 738      na
# 739       P
# 740      na
# 741       M
#
# [742 rows x 42 columns]

# %%
#determine total number of states included in the original data
raw_salary_df['Job Location'].nunique()
# Out:
# 37

# %%
#drop unneccesary columns
salary_df = raw_salary_df[['Rating', 'Lower Salary', 'Upper Salary', 'Avg Salary(K)', 'Job Location', 'job_title_sim', 'seniority_by_title']]
salary_df
# Out:
#      Rating  Lower Salary  Upper Salary  Avg Salary(K) Job Location  \
# 0       3.8            53            91           72.0           NM
# 1       3.4            63           112           87.5           MD
# 2       4.8            80            90           85.0           FL
# 3       3.8            56            97           76.5           WA
# 4       2.9            86           143          114.5           NY
# ..      ...           ...           ...            ...          ...
# 737     3.9            58           111           84.5           MA
# 738     4.4            72           133          102.5           TN
# 739     2.6            56            91           73.5           PA
# 740     3.2            95           160          127.5           PA
# 741     3.6            61           126           93.5           OH
#
#        job_title_sim seniority_by_title
# 0     data scientist                 na
# 1     data scientist                 na
# 2     data scientist                 na
# 3     data scientist                 na
# 4     data scientist                 na
# ..               ...                ...
# 737  other scientist                 sr
# 738    data engineer                 sr
# 739  other scientist                 na
# 740   data scientist                 na
# 741  other scientist                 na
#
# [742 rows x 7 columns]

# %%
#get column types
salary_df.dtypes
# Out:
# Rating                float64
# Lower Salary            int64
# Upper Salary            int64
# Avg Salary(K)         float64
# Job Location           object
# job_title_sim          object
# seniority_by_title     object
# dtype: object

# %%
#convery types to strings
salary_df['Job Location'] = salary_df['Job Location'].astype('string')
salary_df['job_title_sim'] = salary_df['job_title_sim'].astype('string')
salary_df['seniority_by_title'] = salary_df['seniority_by_title'].astype('string')
salary_df.dtypes
# Out:
# /var/folders/hd/ltllzg1x3cd1p6_w0hms1sg00000gn/T/ipykernel_30866/2571449120.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salary_df['Job Location'] = salary_df['Job Location'].astype('string')
# /var/folders/hd/ltllzg1x3cd1p6_w0hms1sg00000gn/T/ipykernel_30866/2571449120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salary_df['job_title_sim'] = salary_df['job_title_sim'].astype('string')
# /var/folders/hd/ltllzg1x3cd1p6_w0hms1sg00000gn/T/ipykernel_30866/2571449120.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salary_df['seniority_by_title'] = salary_df['seniority_by_title'].astype('string')
# Rating                float64
# Lower Salary            int64
# Upper Salary            int64
# Avg Salary(K)         float64
# Job Location           string
# job_title_sim          string
# seniority_by_title     string
# dtype: object

# %%
#determine values in seniority by title
salary_df['seniority_by_title'].value_counts()
# Out:
# na    519
# sr    220
# jr      3
# Name: seniority_by_title, dtype: Int64

# %%
#drop senior and junior positions
salary_df = salary_df[salary_df.seniority_by_title != "sr"]
salary_df = salary_df[salary_df.seniority_by_title != "jr"]
salary_df['seniority_by_title'].value_counts()
# Out:
# na    519
# Name: seniority_by_title, dtype: Int64

# %%
#re-name columns job location to state_code to match other data frame
salary_df = salary_df.rename(columns = {'Job Location': 'state_code'})
salary_df
# Out:
#      Rating  Lower Salary  Upper Salary  Avg Salary(K) state_code  \
# 0       3.8            53            91           72.0         NM
# 1       3.4            63           112           87.5         MD
# 2       4.8            80            90           85.0         FL
# 3       3.8            56            97           76.5         WA
# 4       2.9            86           143          114.5         NY
# ..      ...           ...           ...            ...        ...
# 734     3.6            37           100           68.5         MA
# 735     3.9            62           113           87.5         CA
# 739     2.6            56            91           73.5         PA
# 740     3.2            95           160          127.5         PA
# 741     3.6            61           126           93.5         OH
#
#        job_title_sim seniority_by_title
# 0     data scientist                 na
# 1     data scientist                 na
# 2     data scientist                 na
# 3     data scientist                 na
# 4     data scientist                 na
# ..               ...                ...
# 734   data scientist                 na
# 735    data engineer                 na
# 739  other scientist                 na
# 740   data scientist                 na
# 741  other scientist                 na
#
# [519 rows x 7 columns]

# %%
#number of states after data frame has been manipulated
salary_df['state_code'].nunique()
# Out:
# 36

# %%
#grab median salary by state
salary_df_median = salary_df.groupby(['state_code']).median()
salary_df_median_sale = salary_df_median.sort_values(by='Avg Salary(K)', ascending=False)
salary_df_median_sale.head()
# Out:
#             Rating  Lower Salary  Upper Salary  Avg Salary(K)
# state_code
# CA             3.6          80.0         140.5         110.25
# NJ             3.6          85.0         134.0         109.50
# KY             3.1          68.0         139.0         103.50
# NC             3.7          65.0         126.0          99.50
# OR             3.5          74.5         121.5          98.00

# %%
#grab an salary by state
salary_df_mean = salary_df.groupby(['state_code']).mean()
salary_df_mean_sale = salary_df_mean.sort_values(by='Avg Salary(K)', ascending=False)
salary_df_mean_sale.head()
# Out:
#               Rating  Lower Salary  Upper Salary  Avg Salary(K)
# state_code
# IL          3.566667     84.333333    138.814815     111.574074
# CA          3.606731     80.625000    139.490385     110.057692
# NJ          3.691667     77.666667    131.083333     104.375000
# DC          3.777778     82.000000    123.444444     102.722222
# KY          3.500000     66.333333    127.666667      97.000000

# %%
#merge median dfs
merged_median_df = pd.merge(state_df_median, salary_df_median_sale, how = 'inner', on = 'state_code')
merged_median_df.head()
# Out:
#             median_sale_price  median_ppsf  Rating  Lower Salary  \
# state_code
# AL                   192000.0        111.0    4.25          42.0
# AZ                   292350.0        185.5    3.45          57.0
# CA                   637500.0        417.5    3.60          80.0
# CO                   447000.0        192.0    4.00          64.0
# CT                   278800.0        155.0    3.00          54.0
#
#             Upper Salary  Avg Salary(K)
# state_code
# AL                  76.0          60.75
# AZ                  84.0          69.00
# CA                 140.5         110.25
# CO                 111.0          87.50
# CT                  71.0          62.50

# %%
#determining differential between median salary and price
merged_median_df['cost_vs_salary'] = merged_median_df['median_sale_price'] - (merged_median_df['Avg Salary(K)'] * 1000)
merged_median_df.sort_values(by='cost_vs_salary')
# Out:
#             median_sale_price  median_ppsf  Rating  Lower Salary  \
# state_code
# KY                   183650.0        114.0    3.10          68.0
# OH                   173250.0        110.0    3.50          56.0
# MI                   189850.0        127.0    3.95          65.5
# MO                   179300.0        119.0    4.10          44.0
# IN                   190350.0        102.0    3.95          56.0
# AL                   192000.0        111.0    4.25          42.0
# PA                   221250.0        142.5    3.20          61.0
# IL                   227500.0        147.5    3.70          64.0
# KS                   234150.0        125.0    3.70          61.0
# WI                   205850.0        129.0    3.30          40.0
# NC                   252250.0        142.0    3.70          65.0
# IA                   200600.0        142.0    4.60          31.0
# TN                   256250.0        149.0    3.80          70.0
# NE                   212700.0        119.0    3.20          40.5
# DE                   220050.0        130.0    3.60          43.0
# LA                   223050.0        132.5    3.60          41.0
# GA                   255800.0        141.5    4.70          60.0
# TX                   263000.0        142.0    3.80          64.0
# MN                   268750.0        151.5    4.45          60.0
# MD                   270150.0        169.5    3.55          60.0
# SC                   250700.0        144.5    4.40          39.0
# FL                   274700.0        167.5    4.00          56.0
# CT                   278800.0        155.0    3.00          54.0
# AZ                   292350.0        185.5    3.45          57.0
# NJ                   335250.0        202.0    3.60          85.0
# VA                   355350.0        196.0    4.00          65.0
# OR                   374800.0        225.5    3.50          74.5
# ID                   345250.0        200.0    4.10          39.5
# UT                   374700.0        182.0    4.20          53.0
# NM                   385500.0        244.5    3.50          56.0
# CO                   447000.0        192.0    4.00          64.0
# MA                   483950.0        280.5    3.65          66.5
# NY                   501150.0        290.5    3.70          69.0
# WA                   492800.0        308.5    3.80          56.0
# CA                   637500.0        417.5    3.60          80.0
# DC                   714000.0        454.0    3.50          72.0
#
#             Upper Salary  Avg Salary(K)  cost_vs_salary
# state_code
# KY                 139.0         103.50         80150.0
# OH                 117.0          86.50         86750.0
# MI                 118.0          91.75         98100.0
# MO                 101.0          70.50        108800.0
# IN                  91.0          73.50        116850.0
# AL                  76.0          60.75        131250.0
# PA                 109.0          85.00        136250.0
# IL                 105.0          87.50        140000.0
# KS                 113.0          87.00        147150.0
# WI                  73.0          56.50        149350.0
# NC                 126.0          99.50        152750.0
# IA                  55.0          43.00        157600.0
# TN                 122.0          96.00        160250.0
# NE                  66.0          52.00        160700.0
# DE                  70.0          56.50        163550.0
# LA                  77.5          59.25        163800.0
# GA                  99.0          79.50        176300.0
# TX                 106.0          85.00        178000.0
# MN                 111.0          85.50        183250.0
# MD                 114.5          86.75        183400.0
# SC                  82.0          60.50        190200.0
# FL                  92.5          78.25        196450.0
# CT                  71.0          62.50        216300.0
# AZ                  84.0          69.00        223350.0
# NJ                 134.0         109.50        225750.0
# VA                 113.0          88.00        267350.0
# OR                 121.5          98.00        276800.0
# ID                  73.0          56.25        289000.0
# UT                  91.0          72.00        302700.0
# NM                  95.0          75.50        310000.0
# CO                 111.0          87.50        359500.0
# MA                 123.0          93.00        390950.0
# NY                 121.0          95.00        406150.0
# WA                  97.0          76.50        416300.0
# CA                 140.5         110.25        527250.0
# DC                 121.0          96.50        617500.0

# %%
#determining highest rated state for data science by median rating
merged_median_df.sort_values(by='Rating', ascending=False)
# Out:
#             median_sale_price  median_ppsf  Rating  Lower Salary  \
# state_code
# GA                   255800.0        141.5    4.70          60.0
# IA                   200600.0        142.0    4.60          31.0
# MN                   268750.0        151.5    4.45          60.0
# SC                   250700.0        144.5    4.40          39.0
# AL                   192000.0        111.0    4.25          42.0
# UT                   374700.0        182.0    4.20          53.0
# MO                   179300.0        119.0    4.10          44.0
# ID                   345250.0        200.0    4.10          39.5
# VA                   355350.0        196.0    4.00          65.0
# CO                   447000.0        192.0    4.00          64.0
# FL                   274700.0        167.5    4.00          56.0
# IN                   190350.0        102.0    3.95          56.0
# MI                   189850.0        127.0    3.95          65.5
# WA                   492800.0        308.5    3.80          56.0
# TX                   263000.0        142.0    3.80          64.0
# TN                   256250.0        149.0    3.80          70.0
# KS                   234150.0        125.0    3.70          61.0
# IL                   227500.0        147.5    3.70          64.0
# NC                   252250.0        142.0    3.70          65.0
# NY                   501150.0        290.5    3.70          69.0
# MA                   483950.0        280.5    3.65          66.5
# LA                   223050.0        132.5    3.60          41.0
# DE                   220050.0        130.0    3.60          43.0
# CA                   637500.0        417.5    3.60          80.0
# NJ                   335250.0        202.0    3.60          85.0
# MD                   270150.0        169.5    3.55          60.0
# DC                   714000.0        454.0    3.50          72.0
# NM                   385500.0        244.5    3.50          56.0
# OR                   374800.0        225.5    3.50          74.5
# OH                   173250.0        110.0    3.50          56.0
# AZ                   292350.0        185.5    3.45          57.0
# WI                   205850.0        129.0    3.30          40.0
# PA                   221250.0        142.5    3.20          61.0
# NE                   212700.0        119.0    3.20          40.5
# KY                   183650.0        114.0    3.10          68.0
# CT                   278800.0        155.0    3.00          54.0
#
#             Upper Salary  Avg Salary(K)  cost_vs_salary
# state_code
# GA                  99.0          79.50        176300.0
# IA                  55.0          43.00        157600.0
# MN                 111.0          85.50        183250.0
# SC                  82.0          60.50        190200.0
# AL                  76.0          60.75        131250.0
# UT                  91.0          72.00        302700.0
# MO                 101.0          70.50        108800.0
# ID                  73.0          56.25        289000.0
# VA                 113.0          88.00        267350.0
# CO                 111.0          87.50        359500.0
# FL                  92.5          78.25        196450.0
# IN                  91.0          73.50        116850.0
# MI                 118.0          91.75         98100.0
# WA                  97.0          76.50        416300.0
# TX                 106.0          85.00        178000.0
# TN                 122.0          96.00        160250.0
# KS                 113.0          87.00        147150.0
# IL                 105.0          87.50        140000.0
# NC                 126.0          99.50        152750.0
# NY                 121.0          95.00        406150.0
# MA                 123.0          93.00        390950.0
# LA                  77.5          59.25        163800.0
# DE                  70.0          56.50        163550.0
# CA                 140.5         110.25        527250.0
# NJ                 134.0         109.50        225750.0
# MD                 114.5          86.75        183400.0
# DC                 121.0          96.50        617500.0
# NM                  95.0          75.50        310000.0
# OR                 121.5          98.00        276800.0
# OH                 117.0          86.50         86750.0
# AZ                  84.0          69.00        223350.0
# WI                  73.0          56.50        149350.0
# PA                 109.0          85.00        136250.0
# NE                  66.0          52.00        160700.0
# KY                 139.0         103.50         80150.0
# CT                  71.0          62.50        216300.0

# %%
#merge mean dfs
merged_mean_df = pd.merge(state_df_mean, salary_df_mean_sale, how = 'inner', on = 'state_code')
merged_mean_df.head()
# Out:
#             median_sale_price  median_ppsf    Rating  Lower Salary  \
# state_code
# AL              189148.888889   109.494382  4.212500     40.875000
# AZ              294833.333333   197.627778  3.516667     62.166667
# CA              670961.111111   420.272222  3.606731     80.625000
# CO              458560.000000   207.455556  3.833333     58.333333
# CT              359550.299401   184.581818  3.400000     57.600000
#
#             Upper Salary  Avg Salary(K)
# state_code
# AL             75.000000      57.937500
# AZ            109.833333      86.000000
# CA            139.490385     110.057692
# CO             99.333333      78.833333
# CT             84.600000      71.100000

# %%
#determining differential between mean salary and price
merged_mean_df['cost_vs_salary'] = merged_mean_df['median_sale_price'] - (merged_mean_df['Avg Salary(K)'] * 1000)
merged_mean_df.sort_values(by='cost_vs_salary')
# Out:
#             median_sale_price  median_ppsf    Rating  Lower Salary  \
# state_code
# KY              186930.555556   111.733333  3.500000     66.333333
# OH              169773.888889   103.511111  3.622222     53.222222
# MO              181113.333333   114.316667  4.111111     59.666667
# MI              191853.797468   116.960784  3.950000     65.500000
# IN              179582.876712   101.000000  3.916667     52.333333
# IL              232036.666667   147.055556  3.566667     84.333333
# AL              189148.888889   109.494382  4.212500     40.875000
# PA              220665.555556   146.250000  3.184211     64.947368
# WI              206947.777778   126.877778  3.255556     52.000000
# KS              232371.666667   126.261111  3.700000     61.000000
# IA              202222.448980   138.301370  4.366667     38.666667
# DE              211121.348315   126.140449  3.600000     43.000000
# NE              208931.666667   120.488889  3.275000     39.250000
# NC              253320.555556   148.150000  3.614286     65.571429
# TN              256997.777778   167.155556  3.900000     69.666667
# LA              225518.888889   142.200000  3.575000     40.250000
# MN              266106.111111   158.616667  4.450000     60.000000
# TX              271535.555556   151.594444  3.761905     66.000000
# GA              264038.333333   150.194444  4.433333     61.333333
# MD              280901.111111   162.111111  3.471429     62.750000
# SC              260442.777778   149.544444  4.400000     39.000000
# FL              276862.777778   174.522222  3.966667     57.666667
# AZ              294833.333333   197.627778  3.516667     62.166667
# NJ              348194.444444   265.983333  3.691667     77.666667
# VA              341793.888889   191.183333  3.910714     69.607143
# CT              359550.299401   184.581818  3.400000     57.600000
# OR              383531.666667   236.188889  3.375000     68.250000
# ID              356761.666667   213.622222  4.100000     39.500000
# UT              392304.444444   203.638889  4.042857     51.857143
# NM              401725.766871   251.519481  3.600000     55.000000
# CO              458560.000000   207.455556  3.833333     58.333333
# MA              488262.222222   306.100000  3.415278     69.750000
# WA              486966.666667   301.505556  3.776923     53.769231
# NY              508284.444444   380.516667  3.627451     68.431373
# CA              670961.111111   420.272222  3.606731     80.625000
# DC              724252.222222   453.005556  3.777778     82.000000
#
#             Upper Salary  Avg Salary(K)  cost_vs_salary
# state_code
# KY            127.666667      97.000000    89930.555556
# OH            100.333333      76.777778    92996.111111
# MO            109.777778      84.722222    96391.111111
# MI            118.000000      91.750000   100103.797468
# IN             90.666667      71.500000   108082.876712
# IL            138.814815     111.574074   120462.592593
# AL             75.000000      57.937500   131211.388889
# PA            113.526316      89.236842   131428.713450
# WI             88.555556      70.277778   136670.000000
# KS            113.000000      87.000000   145371.666667
# IA             70.333333      54.500000   147722.448980
# DE             70.000000      56.500000   154621.348315
# NE             69.250000      54.250000   154681.666667
# NC            125.000000      95.285714   158034.841270
# TN            124.000000      96.833333   160164.444444
# LA             75.000000      57.625000   167893.888889
# MN            111.000000      85.500000   180606.111111
# TX            112.380952      89.190476   182345.079365
# GA            101.333333      81.333333   182705.000000
# MD            119.357143      91.053571   189847.539683
# SC             82.000000      60.500000   199942.777778
# FL             88.333333      73.000000   203862.777778
# AZ            109.833333      86.000000   208833.333333
# NJ            131.083333     104.375000   243819.444444
# VA            120.750000      95.178571   246615.317460
# CT             84.600000      71.100000   288450.299401
# OR            116.000000      92.125000   291406.666667
# ID             73.000000      56.250000   300511.666667
# UT             96.714286      74.285714   318018.730159
# NM             93.666667      74.333333   327392.433538
# CO             99.333333      78.833333   379726.666667
# MA            122.097222      95.923611   392338.611111
# WA             94.307692      74.038462   412928.205128
# NY            118.882353      93.656863   414627.581699
# CA            139.490385     110.057692   560903.418803
# DC            123.444444     102.722222   621530.000000

# %%
#determining highest rated state for data science by mean rating
merged_mean_df.sort_values(by='Rating', ascending=False)
# Out:
#             median_sale_price  median_ppsf    Rating  Lower Salary  \
# state_code
# MN              266106.111111   158.616667  4.450000     60.000000
# GA              264038.333333   150.194444  4.433333     61.333333
# SC              260442.777778   149.544444  4.400000     39.000000
# IA              202222.448980   138.301370  4.366667     38.666667
# AL              189148.888889   109.494382  4.212500     40.875000
# MO              181113.333333   114.316667  4.111111     59.666667
# ID              356761.666667   213.622222  4.100000     39.500000
# UT              392304.444444   203.638889  4.042857     51.857143
# FL              276862.777778   174.522222  3.966667     57.666667
# MI              191853.797468   116.960784  3.950000     65.500000
# IN              179582.876712   101.000000  3.916667     52.333333
# VA              341793.888889   191.183333  3.910714     69.607143
# TN              256997.777778   167.155556  3.900000     69.666667
# CO              458560.000000   207.455556  3.833333     58.333333
# DC              724252.222222   453.005556  3.777778     82.000000
# WA              486966.666667   301.505556  3.776923     53.769231
# TX              271535.555556   151.594444  3.761905     66.000000
# KS              232371.666667   126.261111  3.700000     61.000000
# NJ              348194.444444   265.983333  3.691667     77.666667
# NY              508284.444444   380.516667  3.627451     68.431373
# OH              169773.888889   103.511111  3.622222     53.222222
# NC              253320.555556   148.150000  3.614286     65.571429
# CA              670961.111111   420.272222  3.606731     80.625000
# NM              401725.766871   251.519481  3.600000     55.000000
# DE              211121.348315   126.140449  3.600000     43.000000
# LA              225518.888889   142.200000  3.575000     40.250000
# IL              232036.666667   147.055556  3.566667     84.333333
# AZ              294833.333333   197.627778  3.516667     62.166667
# KY              186930.555556   111.733333  3.500000     66.333333
# MD              280901.111111   162.111111  3.471429     62.750000
# MA              488262.222222   306.100000  3.415278     69.750000
# CT              359550.299401   184.581818  3.400000     57.600000
# OR              383531.666667   236.188889  3.375000     68.250000
# NE              208931.666667   120.488889  3.275000     39.250000
# WI              206947.777778   126.877778  3.255556     52.000000
# PA              220665.555556   146.250000  3.184211     64.947368
#
#             Upper Salary  Avg Salary(K)  cost_vs_salary
# state_code
# MN            111.000000      85.500000   180606.111111
# GA            101.333333      81.333333   182705.000000
# SC             82.000000      60.500000   199942.777778
# IA             70.333333      54.500000   147722.448980
# AL             75.000000      57.937500   131211.388889
# MO            109.777778      84.722222    96391.111111
# ID             73.000000      56.250000   300511.666667
# UT             96.714286      74.285714   318018.730159
# FL             88.333333      73.000000   203862.777778
# MI            118.000000      91.750000   100103.797468
# IN             90.666667      71.500000   108082.876712
# VA            120.750000      95.178571   246615.317460
# TN            124.000000      96.833333   160164.444444
# CO             99.333333      78.833333   379726.666667
# DC            123.444444     102.722222   621530.000000
# WA             94.307692      74.038462   412928.205128
# TX            112.380952      89.190476   182345.079365
# KS            113.000000      87.000000   145371.666667
# NJ            131.083333     104.375000   243819.444444
# NY            118.882353      93.656863   414627.581699
# OH            100.333333      76.777778    92996.111111
# NC            125.000000      95.285714   158034.841270
# CA            139.490385     110.057692   560903.418803
# NM             93.666667      74.333333   327392.433538
# DE             70.000000      56.500000   154621.348315
# LA             75.000000      57.625000   167893.888889
# IL            138.814815     111.574074   120462.592593
# AZ            109.833333      86.000000   208833.333333
# KY            127.666667      97.000000    89930.555556
# MD            119.357143      91.053571   189847.539683
# MA            122.097222      95.923611   392338.611111
# CT             84.600000      71.100000   288450.299401
# OR            116.000000      92.125000   291406.666667
# NE             69.250000      54.250000   154681.666667
# WI             88.555556      70.277778   136670.000000
# PA            113.526316      89.236842   131428.713450

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
#define the data science housing data base in Mongo
db = client.ds_housing_db

# %%
#declare the median and mean collections
median = db.median
mean = db.mean

# %%
#insert median data frame in to median collection
median.insert_many(merged_median_df.to_dict('records'))

# %%
#insert mean data frame in to mean collection
mean.insert_many(merged_mean_df.to_dict('records'))
